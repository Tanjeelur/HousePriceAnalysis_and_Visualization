# %%
#Dowanload the Dataset from the google drive:
! gdown  1qF3zvu_MFS2DWmN8pqWTG5aFXxGFQgJX
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1qF3zvu_MFS2DWmN8pqWTG5aFXxGFQgJX
# To: /content/house_listings.csv
# 100% 1.92M/1.92M [00:00<00:00, 171MB/s]

# %%
#Import the neccessary libraries:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load the csv file to the dataframe:
df = pd.read_csv('house_listings.csv')
df.head(10)
# Out:
#                                      address   price est_monthly_payment  \
# 0            269 Holley St, Biloxi, MS 39530  200000                 NaN
# 1            132 Dukate St, Biloxi, MS 39530  350000                 NaN
# 2     1130 Beach Blvd #408, Biloxi, MS 39530  280000                 NaN
# 3          2350 Rue Maison, Biloxi, MS 39532  484000                 NaN
# 4    11512 Holly Bluff Cir, Biloxi, MS 39532  355000                 NaN
# 5  14231 Woodland Hills Dr, Biloxi, MS 39532  350000                 NaN
# 6  15171 Haversham Pl, D'Iberville, MS 39540  295000                 NaN
# 7                                        NaN  327900                 NaN
# 8             345 Bowen St, Biloxi, MS 39530  250000                 NaN
# 9          179 Gardenia St, Biloxi, MS 39531  119000                 NaN
#
#   bedrooms bathrooms square_footage  property_type  year_built  lot_size  \
# 0        3       2.5           1250  Single-family      2013.0    5662.0
# 1        2         2           1378  Single-family      1900.0    5662.0
# 2        2         2           1517          Condo      1981.0  145926.0
# 3        4       3.5           2687  Single-family      2004.0   10890.0
# 4        3         2           2043  Single-family      1996.0   44431.0
# 5        3         2           1954  Single-family      1993.0  339768.0
# 6        4         2           2547  Single-family      2006.0    9583.0
# 7        5         3           2100  Single-family      2025.0   13503.0
# 8        3         2           2219  Single-family      2007.0    5662.0
# 9        1         1            800  Single-family      1950.0    8712.0
#
#   price_per_sqft  parking        state        city  \
# 0            160      4.0  Mississippi  Biloxi, MS
# 1            254      1.0  Mississippi  Biloxi, MS
# 2            185      NaN  Mississippi  Biloxi, MS
# 3            180      2.0  Mississippi  Biloxi, MS
# 4            174      2.0  Mississippi  Biloxi, MS
# 5            179      6.0  Mississippi  Biloxi, MS
# 6            116      2.0  Mississippi  Biloxi, MS
# 7            156      NaN  Mississippi  Biloxi, MS
# 8            113      2.0  Mississippi  Biloxi, MS
# 9            149      2.0  Mississippi  Biloxi, MS
#
#                                                  url
# 0  https://www.redfin.com/MS/Biloxi/269-Holley-St...
# 1  https://www.redfin.com/MS/Biloxi/132-Dukate-St...
# 2  https://www.redfin.com/MS/Biloxi/1130-Beach-Bl...
# 3  https://www.redfin.com/MS/Biloxi/2350-Rue-Mais...
# 4  https://www.redfin.com/MS/Biloxi/11512-Holly-B...
# 5  https://www.redfin.com/MS/Biloxi/14231-Woodlan...
# 6  https://www.redfin.com/MS/Diberville/15171-Hav...
# 7  https://www.redfin.com/MS/Biloxi/9574-Reserve-...
# 8  https://www.redfin.com/MS/Biloxi/345-Bowen-St-...
# 9  https://www.redfin.com/MS/Biloxi/179-Gardenia-...

# %%
#Removing the monthly installment column form the dataset:
df.drop('est_monthly_payment', axis=1, inplace=True)

# %%
#Removing the Null values and fill them

#Removing the rows which have - this value from the dataset
df = df[~df['square_footage'].astype(str).str.contains('—')]
df=df.dropna(subset=['square_footage'])

#Removing the rows which Null values
df=df.dropna(subset=['address','property_type','price'])

#Fill the null values with 0 for parking
df['parking'].fillna(0, inplace=True)
# Out:
# /tmp/ipython-input-2862232024.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['parking'].fillna(0, inplace=True)

# %%
#Convert the object type values to Numaric values:
df['price'] = pd.to_numeric(df['price'], errors='coerce')
df['square_footage'] = pd.to_numeric(df['square_footage'], errors='coerce')
df["bedrooms"] = pd.to_numeric(df["bedrooms"], errors="coerce")
df["bathrooms"] = pd.to_numeric(df["bathrooms"], errors="coerce")
df["price_per_sqft"] = pd.to_numeric(df["price_per_sqft"], errors="coerce")

# %%
# Convert acres to square feet for values under 100 in 'square_footage'
df['square_footage'] = df.apply(lambda row: row['square_footage'] * 43560 if row['square_footage'] < 500 and isinstance(row['square_footage'], float) and row['property_type'] == 'Vacant land' else row['square_footage'], axis=1)

#calulating the price per squarefit manually for price per squarefit column
df['price_per_sqft'] = df.apply(lambda row: row['price'] / row['square_footage'] if pd.isnull(row['price_per_sqft']) and not pd.isnull(row['price']) and not pd.isnull(row['square_footage']) else row['price_per_sqft'], axis=1)

# %%
df.isnull().sum()
# Out:
# address           0
# price             0
# bedrooms          0
# bathrooms         0
# square_footage    0
# property_type     0
# year_built        0
# lot_size          0
# price_per_sqft    0
# parking           0
# state             0
# city              0
# url               0
# dtype: int64

# %%
#Ectract the city name from the address for city column
def extract_city(address):
    if isinstance(address, str):
        parts = address.split(',')
        if len(parts) >= 2:
            city_state_zip = parts[-2].strip()
            city = city_state_zip.rsplit(' ', 1)[0] # Split by the last space to remove zip
            return city
    return None

df['city'] = df['address'].apply(extract_city)
display(df.head())
# Out:
#                                    address     price  bedrooms  bathrooms  \
# 0          269 Holley St, Biloxi, MS 39530  200000.0       3.0        2.5
# 1          132 Dukate St, Biloxi, MS 39530  350000.0       2.0        2.0
# 2   1130 Beach Blvd #408, Biloxi, MS 39530  280000.0       2.0        2.0
# 3        2350 Rue Maison, Biloxi, MS 39532  484000.0       4.0        3.5
# 4  11512 Holly Bluff Cir, Biloxi, MS 39532  355000.0       3.0        2.0
#
#    square_footage  property_type  year_built  lot_size  price_per_sqft  \
# 0          1250.0  Single-family      2013.0    5662.0           160.0
# 1          1378.0  Single-family      1900.0    5662.0           254.0
# 2          1517.0          Condo      1981.0  145926.0           185.0
# 3          2687.0  Single-family      2004.0   10890.0           180.0
# 4          2043.0  Single-family      1996.0   44431.0           174.0
#
#    parking        state    city  \
# 0      4.0  Mississippi  Biloxi
# 1      1.0  Mississippi  Biloxi
# 2      0.0  Mississippi  Biloxi
# 3      2.0  Mississippi  Biloxi
# 4      2.0  Mississippi  Biloxi
#
#                                                  url
# 0  https://www.redfin.com/MS/Biloxi/269-Holley-St...
# 1  https://www.redfin.com/MS/Biloxi/132-Dukate-St...
# 2  https://www.redfin.com/MS/Biloxi/1130-Beach-Bl...
# 3  https://www.redfin.com/MS/Biloxi/2350-Rue-Mais...
# 4  https://www.redfin.com/MS/Biloxi/11512-Holly-B...

# %%
#fill the bed and bathroom with 0 if the land type is vacant
df.loc[df['property_type'] == 'Vacant land', ['bedrooms', 'bathrooms']] = 0
df=df.dropna(subset=['bathrooms'])

# %%
#fill the null values of year built column with 0
df['year_built'] = df['year_built'].fillna(0)

# %%
#fill the null lot size values with 0
df['lot_size'].fillna(0, inplace=True)

#drop null values of squarte footage column
df.dropna(subset=['square_footage'], inplace=True)

#drop null values of bedroom column
df.dropna(subset=['bedrooms'], inplace=True)

#drop null values of price column
df.dropna(subset=['price'], inplace=True)
# Out:
# /tmp/ipython-input-196126432.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['lot_size'].fillna(0, inplace=True)

# %%
df.isnull().sum()
# Out:
# address           0
# price             0
# bedrooms          0
# bathrooms         0
# square_footage    0
# property_type     0
# year_built        0
# lot_size          0
# price_per_sqft    0
# parking           0
# state             0
# city              0
# url               0
# dtype: int64

# %%
#Making some corrections to the property type values:
df = df[df['property_type'] != 'Parking']
df['property_type'] = df['property_type'].replace('Condo (co-op)', 'Condo')
df['property_type'] = df['property_type'].replace('Single Family Residence, 24 - Floating Home/On-Water Res', 'Single-family')
df['property_type'] = df['property_type'].replace('Townhome (co-op)', 'Townhome')

df
# Out:
#                                                  address     price  bedrooms  \
# 0                        269 Holley St, Biloxi, MS 39530  200000.0       3.0
# 1                        132 Dukate St, Biloxi, MS 39530  350000.0       2.0
# 2                 1130 Beach Blvd #408, Biloxi, MS 39530  280000.0       2.0
# 3                      2350 Rue Maison, Biloxi, MS 39532  484000.0       4.0
# 4                11512 Holly Bluff Cir, Biloxi, MS 39532  355000.0       3.0
# ...                                                  ...       ...       ...
# 10717          2101 S 324 St #107, Federal Way, WA 98003  169000.0       2.0
# 10718  33010 17th Pl S Unit A-108, Federal Way, WA 98003  250000.0       2.0
# 10719         2611 S 288th St #61, Federal Way, WA 98003  142500.0       3.0
# 10720  31867 48th Cir SW Unit 14A, Federal Way, WA 98023  598000.0       2.0
# 10721           32622 39th Ave SW, Federal Way, WA 98023  625000.0       4.0
#
#        bathrooms  square_footage  property_type  year_built  lot_size  \
# 0            2.5          1250.0  Single-family      2013.0    5662.0
# 1            2.0          1378.0  Single-family      1900.0    5662.0
# 2            2.0          1517.0          Condo      1981.0  145926.0
# 3            3.5          2687.0  Single-family      2004.0   10890.0
# 4            2.0          2043.0  Single-family      1996.0   44431.0
# ...          ...             ...            ...         ...       ...
# 10717        2.0          1248.0   Manufactured      2020.0    2800.0
# 10718        1.0           774.0          Condo      1978.0       0.0
# 10719        2.0          1568.0   Manufactured      1990.0       0.0
# 10720        2.0          1670.0          Condo      2000.0       0.0
# 10721        2.0          1670.0  Single-family      1968.0    8160.0
#
#        price_per_sqft  parking        state     city  \
# 0               160.0      4.0  Mississippi   Biloxi
# 1               254.0      1.0  Mississippi   Biloxi
# 2               185.0      0.0  Mississippi   Biloxi
# 3               180.0      2.0  Mississippi   Biloxi
# 4               174.0      2.0  Mississippi   Biloxi
# ...               ...      ...          ...      ...
# 10717           135.0      2.0   Washington  Federal
# 10718           323.0      1.0   Washington  Federal
# 10719            91.0      2.0   Washington  Federal
# 10720           358.0      1.0   Washington  Federal
# 10721           374.0      0.0   Washington  Federal
#
#                                                      url
# 0      https://www.redfin.com/MS/Biloxi/269-Holley-St...
# 1      https://www.redfin.com/MS/Biloxi/132-Dukate-St...
# 2      https://www.redfin.com/MS/Biloxi/1130-Beach-Bl...
# 3      https://www.redfin.com/MS/Biloxi/2350-Rue-Mais...
# 4      https://www.redfin.com/MS/Biloxi/11512-Holly-B...
# ...                                                  ...
# 10717  https://www.redfin.com/WA/Federal-Way/2101-S-3...
# 10718  https://www.redfin.com/WA/Federal-Way/33010-17...
# 10719  https://www.redfin.com/WA/Federal-Way/2611-S-2...
# 10720  https://www.redfin.com/WA/Federal-Way/31867-48...
# 10721  https://www.redfin.com/WA/Federal-Way/32622-39...
#
# [9871 rows x 13 columns]

# %%
df.to_csv('cleaned_house_listings.csv', index=False)
